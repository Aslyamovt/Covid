"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Macau","City":"","CityCode":"","Lat":"22.17","Lon":"113.55","Cases":45,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Zhejiang","City":"","CityCode":"","Lat":"29.18","Lon":"120.09","Cases":1268,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Heilongjiang","City":"","CityCode":"","Lat":"47.86","Lon":"127.76","Cases":921,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Henan","City":"","CityCode":"","Lat":"33.88","Lon":"113.61","Cases":1276,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Hong Kong","City":"","CityCode":"","Lat":"22.3","Lon":"114.2","Cases":1033,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Hubei","City":"","CityCode":"","Lat":"30.98","Lon":"112.27","Cases":68128,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Ningxia","City":"","CityCode":"","Lat":"37.27","Lon":"106.17","Cases":75,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Qinghai","City":"","CityCode":"","Lat":"35.75","Lon":"96","Cases":18,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Shaanxi","City":"","CityCode":"","Lat":"35.19","Lon":"108.87","Cases":279,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Shandong","City":"","CityCode":"","Lat":"36.34","Lon":"118.15","Cases":787,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Fujian","City":"","CityCode":"","Lat":"26.08","Lon":"117.99","Cases":355,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Gansu","City":"","CityCode":"","Lat":"37.81","Lon":"101.06","Cases":139,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Guangdong","City":"","CityCode":"","Lat":"23.34","Lon":"113.42","Cases":1582,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Guangxi","City":"","CityCode":"","Lat":"23.83","Lon":"108.79","Cases":254,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Guizhou","City":"","CityCode":"","Lat":"26.82","Lon":"106.87","Cases":147,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Hainan","City":"","CityCode":"","Lat":"19.2","Lon":"109.75","Cases":168,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Hebei","City":"","CityCode":"","Lat":"39.55","Lon":"116.13","Cases":328,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"China","CountryCode":"CN","Province":"Zhejiang","City":"","CityCode":"","Lat":"29.18","Lon":"120.09","Cases":1268,"Status":"confirmed","Date":"2020-04-23T00:00:00Z"}]

# %%
import math

total=[]
i=0
past='2020-01-22T00:00:00Z'
while i<len(a):
    cases=0
    while b[i]['Date']==past:
        cases+=b[i]['Cases']
        past = b[i]['Date']
        i+=1
    total.append(cases)
    past = b[i]['Date']
    i+=1

# %%
increasing=[]
for i in range(len(total)-1):
    increasing.append(total[i+1]-total[i])

# %%
# %matplotlib inline
from fitter import Fitter

f = Fitter(increasing)
f.fit()
f.summary()
# Out:
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_distn_infrastructure.py:2407: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:422: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.0/np.pi/np.sqrt(x*(1-x))
# Fitted alpha distribution with error=2.205996217050497e-06)
# Fitted anglit distribution with error=1.461534435775197e-06)
# Fitted arcsine distribution with error=1.7119856605176207e-06)
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:7953: RuntimeWarning: divide by zero encountered in double_scalars
#   return chi**3 / (_norm_pdf_C * _argus_phi(chi)) * x * np.sqrt(y) * np.exp(-chi**2 * y / 2)
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:547: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# ...

# %%
d=[{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":1,"Status":"confirmed","Date":"2020-01-22T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":1,"Status":"confirmed","Date":"2020-01-23T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":2,"Status":"confirmed","Date":"2020-01-24T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":2,"Status":"confirmed","Date":"2020-01-25T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":3,"Status":"confirmed","Date":"2020-01-26T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":4,"Status":"confirmed","Date":"2020-01-27T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":4,"Status":"confirmed","Date":"2020-01-28T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":4,"Status":"confirmed","Date":"2020-01-29T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":4,"Status":"confirmed","Date":"2020-01-30T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":11,"Status":"confirmed","Date":"2020-01-31T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":12,"Status":"confirmed","Date":"2020-02-01T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":15,"Status":"confirmed","Date":"2020-02-02T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":15,"Status":"confirmed","Date":"2020-02-03T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":16,"Status":"confirmed","Date":"2020-02-04T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":19,"Status":"confirmed","Date":"2020-02-05T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":23,"Status":"confirmed","Date":"2020-02-06T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":24,"Status":"confirmed","Date":"2020-02-07T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":24,"Status":"confirmed","Date":"2020-02-08T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":25,"Status":"confirmed","Date":"2020-02-09T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":27,"Status":"confirmed","Date":"2020-02-10T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":28,"Status":"confirmed","Date":"2020-02-11T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":28,"Status":"confirmed","Date":"2020-02-12T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":28,"Status":"confirmed","Date":"2020-02-13T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":28,"Status":"confirmed","Date":"2020-02-14T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":28,"Status":"confirmed","Date":"2020-02-15T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":29,"Status":"confirmed","Date":"2020-02-16T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":30,"Status":"confirmed","Date":"2020-02-17T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":31,"Status":"confirmed","Date":"2020-02-18T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":31,"Status":"confirmed","Date":"2020-02-19T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":104,"Status":"confirmed","Date":"2020-02-20T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":204,"Status":"confirmed","Date":"2020-02-21T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":433,"Status":"confirmed","Date":"2020-02-22T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":602,"Status":"confirmed","Date":"2020-02-23T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":833,"Status":"confirmed","Date":"2020-02-24T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":977,"Status":"confirmed","Date":"2020-02-25T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":1261,"Status":"confirmed","Date":"2020-02-26T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":1766,"Status":"confirmed","Date":"2020-02-27T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":2337,"Status":"confirmed","Date":"2020-02-28T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":3150,"Status":"confirmed","Date":"2020-02-29T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":3736,"Status":"confirmed","Date":"2020-03-01T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":4335,"Status":"confirmed","Date":"2020-03-02T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":5186,"Status":"confirmed","Date":"2020-03-03T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":5621,"Status":"confirmed","Date":"2020-03-04T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":6088,"Status":"confirmed","Date":"2020-03-05T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":6593,"Status":"confirmed","Date":"2020-03-06T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7041,"Status":"confirmed","Date":"2020-03-07T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7314,"Status":"confirmed","Date":"2020-03-08T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7478,"Status":"confirmed","Date":"2020-03-09T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7513,"Status":"confirmed","Date":"2020-03-10T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7755,"Status":"confirmed","Date":"2020-03-11T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7869,"Status":"confirmed","Date":"2020-03-12T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":7979,"Status":"confirmed","Date":"2020-03-13T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8086,"Status":"confirmed","Date":"2020-03-14T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8162,"Status":"confirmed","Date":"2020-03-15T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8236,"Status":"confirmed","Date":"2020-03-16T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8320,"Status":"confirmed","Date":"2020-03-17T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8413,"Status":"confirmed","Date":"2020-03-18T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8565,"Status":"confirmed","Date":"2020-03-19T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8652,"Status":"confirmed","Date":"2020-03-20T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8799,"Status":"confirmed","Date":"2020-03-21T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8961,"Status":"confirmed","Date":"2020-03-22T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":8961,"Status":"confirmed","Date":"2020-03-23T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9037,"Status":"confirmed","Date":"2020-03-24T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9137,"Status":"confirmed","Date":"2020-03-25T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9241,"Status":"confirmed","Date":"2020-03-26T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9332,"Status":"confirmed","Date":"2020-03-27T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9478,"Status":"confirmed","Date":"2020-03-28T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9583,"Status":"confirmed","Date":"2020-03-29T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9661,"Status":"confirmed","Date":"2020-03-30T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9786,"Status":"confirmed","Date":"2020-03-31T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9887,"Status":"confirmed","Date":"2020-04-01T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":9976,"Status":"confirmed","Date":"2020-04-02T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10062,"Status":"confirmed","Date":"2020-04-03T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10156,"Status":"confirmed","Date":"2020-04-04T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10237,"Status":"confirmed","Date":"2020-04-05T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10284,"Status":"confirmed","Date":"2020-04-06T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10331,"Status":"confirmed","Date":"2020-04-07T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10384,"Status":"confirmed","Date":"2020-04-08T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10423,"Status":"confirmed","Date":"2020-04-09T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10450,"Status":"confirmed","Date":"2020-04-10T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10480,"Status":"confirmed","Date":"2020-04-11T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10512,"Status":"confirmed","Date":"2020-04-12T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10537,"Status":"confirmed","Date":"2020-04-13T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10564,"Status":"confirmed","Date":"2020-04-14T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10591,"Status":"confirmed","Date":"2020-04-15T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10613,"Status":"confirmed","Date":"2020-04-16T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10635,"Status":"confirmed","Date":"2020-04-17T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10653,"Status":"confirmed","Date":"2020-04-18T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10661,"Status":"confirmed","Date":"2020-04-19T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10674,"Status":"confirmed","Date":"2020-04-20T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10683,"Status":"confirmed","Date":"2020-04-21T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10694,"Status":"confirmed","Date":"2020-04-22T00:00:00Z"},{"Country":"Korea (South)","CountryCode":"KR","Province":"","City":"","CityCode":"","Lat":"35.91","Lon":"127.77","Cases":10694,"Status":"confirmed","Date":"2020-04-23T00:00:00Z"}]

# %%
total_sk=[]
for i in range(len(d)):
    total_sk.append(d[i]['Cases'])

# %%
increasing_sk=[]
for i in range(len(total_sk)-1):
    increasing_sk.append(total_sk[i+1]-total_sk[i])

# %%
# %matplotlib inline
from fitter import Fitter

f = Fitter(increasing_sk[26:])
f.fit()
f.summary()
# Out:
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_distn_infrastructure.py:2407: RuntimeWarning:
#
# invalid value encountered in double_scalars
# Fitted alpha distribution with error=0.0031395145657651395)
# Fitted anglit distribution with error=0.0004634190905379459)
# Fitted arcsine distribution with error=0.0004203143556863366)
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:7953: RuntimeWarning:
#
# divide by zero encountered in double_scalars
#
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:547: RuntimeWarning:
#
# invalid value encountered in sqrt
# Fitted argus distribution with error=0.0006352248491023598)
# Fitted beta distribution with error=0.0002891565899412435)
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:708: RuntimeWarning:
#
# divide by zero encountered in true_divide
#
# d:\anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:712: RuntimeWarning:
#
# ...

# %%
import requests
# %matplotlib inline
from fitter import Fitter

# %%
def load_data(name):
    response = requests.get('https://api.covid19api.com/country/'+name+'/status/confirmed/live')
    a=response.json()
    response = requests.get('https://api.covid19api.com/country/'+name+'/status/deaths/live')
    b=response.json()
    response = requests.get('https://api.covid19api.com/country/'+name+'/status/recovered/live')
    c=response.json()

    recs=[]
    total=[]
    inf=[]
    dead=[]
    inc=[]
    dead_inc=[]
    for i in range(len(a)):
        recs.append(c[i]['Cases'])
        total.append(a[i]['Cases'])
        dead.append(b[i]['Cases'])
        inf.append(a[i]['Cases']-b[i]['Cases']-c[i]['Cases'])
    recs=recs[:len(recs)-1]
    total=total[:len(total)-1]
    inf=inf[:len(inf)-1]
    dead=dead[:len(dead)-1]
    inc=inc[:len(inc)-1]
    dead_inc=dead_inc[:len(dead_inc)-1]

    dead_inc.append(dead[0])
    inc.append(total[0])
    for i in range(len(dead)-1):
        dead_inc.append(dead[i+1]-dead[i])
        inc.append(total[i+1]-total[i])

    return recs, total, inf, dead, inc, dead_inc

# %%
data = load_data('Italy')

# %%
f = Fitter(data[2])
f.fit()
f.summary()
# Out:
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_distn_infrastructure.py:2407: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:422: RuntimeWarning: divide by zero encountered in true_divide
#   return 1.0/np.pi/np.sqrt(x*(1-x))
# Fitted alpha distribution with error=1.130498661679016e-07)
# Fitted anglit distribution with error=1.1287689806234698e-07)
# Fitted arcsine distribution with error=1.0684587015442346e-07)
# Fitted argus distribution with error=1.128361264331769e-07)
# Fitted beta distribution with error=1.1056776332702517e-07)
# Fitted betaprime distribution with error=6.634317866699645e-08)
# Fitted bradford distribution with error=1.0652208336776902e-07)
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:547: RuntimeWarning: invalid value encountered in sqrt
#   sk = 2*(b-a)*np.sqrt(a + b + 1) / (a + b + 2) / np.sqrt(a*b)
# ...

# %%
data2 = load_data('Germany')
f = Fitter(data2[2])
f.fit()
f.summary()
# Out:
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_distn_infrastructure.py:2407: RuntimeWarning: invalid value encountered in double_scalars
#   Lhat = muhat - Shat*mu
# Fitted alpha distribution with error=3.128920041382693e-07)
# Fitted anglit distribution with error=3.1572126129460636e-07)
# Fitted arcsine distribution with error=2.626632781931966e-07)
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:7953: RuntimeWarning: divide by zero encountered in double_scalars
#   return chi**3 / (_norm_pdf_C * _argus_phi(chi)) * x * np.sqrt(y) * np.exp(-chi**2 * y / 2)
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:708: RuntimeWarning: divide by zero encountered in true_divide
#   a/(b-1.0),
# D:\Anaconda3\envs\nlp\lib\site-packages\scipy\stats\_continuous_distns.py:712: RuntimeWarning: divide by zero encountered in true_divide
#   a*(a+1.0)/((b-2.0)*(b-1.0)),
# ...
